# %% [markdown]
# <a href="https://colab.research.google.com/github/Dragonkingkov/Movie-recommender-system/blob/main/recc_sys_dataset2020_to_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data_old=pd.read_csv('/content/final_dataset.csv')

# %%
data_old
# Out:
#       Unnamed: 0      director_name           actor_1_name      actor_2_name  \
# 0              0      James Cameron            CCH Pounder  Joel David Moore
# 1              1     Gore Verbinski            Johnny Depp     Orlando Bloom
# 2              2         Sam Mendes        Christoph Waltz      Rory Kinnear
# 3              3  Christopher Nolan              Tom Hardy    Christian Bale
# 4              4        Doug Walker            Doug Walker        Rob Walker
# ...          ...                ...                    ...               ...
# 5903        5903        Pete Docter             Jamie Foxx          Tina Fey
# 5904        5904   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 5905        5905        Regina King      Kingsley Ben-Adir         Eli Goree
# 5906        5906    Emerald Fennell         Carey Mulligan        Bo Burnham
# 5907        5907   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
# ...

# %%
import requests
import bs4 as bs
import urllib.request
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')
tables = soup.find_all('table',class_='wikitable sortable')

# %%
import pandas as pd
from io import StringIO

df1 = pd.read_html(StringIO(str(tables[0])))[0]
df2 = pd.read_html(StringIO(str(tables[1])))[0]
df3 = pd.read_html(StringIO(str(tables[2])))[0]
df4 = pd.read_html(StringIO(str(tables[3]).replace("'1\"\'", '"1"')))[0]

# %%
df1
# Out:
#           Opening  Opening.1                            Title  \
# 0   J A N U A R Y          1              Shadow in the Cloud
# 1   J A N U A R Y          5                          Hacksaw
# 2   J A N U A R Y         12  Dr. Bird's Advice for Sad Poets
# 3   J A N U A R Y         13                  The White Tiger
# 4   J A N U A R Y         14                      Locked Down
# ..            ...        ...                              ...
# 65      M A R C H         26                  The Seventh Day
# 66      M A R C H         26                    Senior Moment
# 67      M A R C H         26                  North Hollywood
# 68      M A R C H         26         Shoplifters of the World
# 69      M A R C H         31                Godzilla vs. Kong
#
#                                    Production company  \
# 0                              Vertical Entertainment
# 1                    Leone Films / Midnight Releasing
# 2            Relativity Media / Ketchup Entertainment
# ...

# %%
df=pd.concat([df1,df2,df3,df4],ignore_index=True)

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                                Title  \
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 361           The Tragedy of Macbeth
# 362             A Journal for Jordan
# 363                American Underdog
# 364                          Memoria
# 365                              NaN
#
#                                          Cast and crew
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...
# 4    Doug Liman (director); Steven Knight (screenpl...
# ..                                                 ...
# 361  Joel Coen (director/screenplay); Denzel Washin...
# 362  Denzel Washington (director); Virgil Williams ...
# ...

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key ='e4043adeb855ecd524f5c673c9524f4f'

# %%
from tmdbv3api import Movie
import numpy as np
import requests
import time

tmdb_movie = Movie()

def get_genre(x):
    try:
        # Add a small delay to avoid hitting API rate limits
        time.sleep(0.25)

        # Handle empty or invalid titles
        if pd.isna(x) or x == '':
            return np.NaN

        # Search for the movie
        result = tmdb_movie.search(x)

        if not result:
            return np.NaN

        # Get the first movie result
        movie_id = result[0].id

        # Make API request for movie details
        response = requests.get(
            f'https://api.themoviedb.org/3/movie/{movie_id}',
            params={'api_key': tmdb.api_key}
        )

        # Check if request was successful
        if response.status_code != 200:
            return np.NaN

        data_json = response.json()

        # Extract genres
        if data_json.get('genres'):
            genres = [genre['name'] for genre in data_json['genres']]
            return ' '.join(genres)

        return np.NaN

    except Exception as e:
        print(f"Error processing title '{x}': {str(e)}")
        return np.NaN

# Apply the function to the dataframe with progress tracking
from tqdm import tqdm
tqdm.pandas()
df_2021['genres'] = df_2021['Title'].progress_map(lambda x: get_genre(str(x)))
# Out:
#  68%|██████▊   | 248/366 [02:18<00:59,  1.97it/s]
# Error processing title 'Dating and New York': getattr(): attribute name must be string
# 100%|██████████| 366/366 [03:24<00:00,  1.79it/s]
# <ipython-input-17-b24a8cdeb750>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].progress_map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                                Title  \
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 361           The Tragedy of Macbeth
# 362             A Journal for Jordan
# 363                American Underdog
# 364                          Memoria
# 365                              NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...
# 4    Doug Liman (director); Steven Knight (screenpl...
# ..                                                 ...
# 361  Joel Coen (director/screenplay); Denzel Washin...
# 362  Denzel Washington (director); Virgil Williams ...
# ...

# %% [markdown]
# **Getting director deatails from cast and crew**

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021.loc[:,'director_name'] = df_2021.loc[:,'Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021.loc[:,'actor_1_name'] = df_2021.loc[:,'Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-23-d74a0e9331d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021.loc[:,'actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021.loc[:,'actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021.loc[:,'actor_3_name'] = df_2021.loc[:,'Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
df_21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Anthony Leone
# 2                                            Yaniv Raz
# 3                                        Ramin Bahrani
# 4                                           Doug Liman
# ..                                                 ...
# 361                                          Joel Coen
# 362                                  Denzel Washington
# 363                                     Erwin brothers
# 364  Apichatpong Weerasethakul (director/acreenplay...
# 365                                                nan
#
#                                           actor_1_name          actor_2_name  \
# 0                                   Chloë Grace Moretz     Taylor John Smith
# 1                                              Amy Cay  Brian Patrick Butler
# ...

# %%
df_21['comb'] = df_21['actor_1_name'] + ' ' + df_21['actor_2_name'] + ' '+ df_21['actor_3_name'] + ' '+ df_21['director_name'] +' ' + df_21['genres']

# %%
df_21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Anthony Leone
# 2                                            Yaniv Raz
# 3                                        Ramin Bahrani
# 4                                           Doug Liman
# ..                                                 ...
# 361                                          Joel Coen
# 362                                  Denzel Washington
# 363                                     Erwin brothers
# 364  Apichatpong Weerasethakul (director/acreenplay...
# 365                                                nan
#
#                                           actor_1_name          actor_2_name  \
# 0                                   Chloë Grace Moretz     Taylor John Smith
# 1                                              Amy Cay  Brian Patrick Butler
# ...

# %%
df_21=df_21.dropna(how='any')

# %%
df_21.loc[:,'movie_title']=df_21.loc[:,'movie_title'].str.lower()

# %%
data_old.columns
# Out:
# Index(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
data_old=data_old.drop(columns='Unnamed: 0')

# %%
df_old=pd.concat([data_old,df_21],ignore_index=True)

# %%
df_old
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6242                                     Matthew Vaughn
# 6243                                          Joel Coen
# 6244                                  Denzel Washington
# 6245                                     Erwin brothers
# 6246  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# ...

# %% [markdown]
# # **2022 movies**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')
tables = soup.find_all('table',class_='wikitable sortable')

# %%
import pandas as pd
from io import StringIO

df1 = pd.read_html(StringIO(str(tables[0])))[0]
df2 = pd.read_html(StringIO(str(tables[1])))[0]
df3 = pd.read_html(StringIO(str(tables[2])))[0]
df4 = pd.read_html(StringIO(str(tables[3]).replace("'1\"\'", '"1"')))[0]

# %%
df=pd.concat([df1,df2,df3,df4],ignore_index=True)
df_2022 = df[['Title','Cast and crew']]
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 316            Alice, Darling
# 317                       NaN
# 318                       NaN
# 319                       NaN
# 320                       NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director); José Prende...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward John Drake (director/screenplay); Timot...
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 316  Mary Nighy (director); Alanna Francis (screenp...
# 317                                                NaN
# 318                                                NaN
# ...

# %%
df_2022.columns
# Out:
# Index(['Title', 'Cast and crew'], dtype='object')

# %%
from tmdbv3api import Movie
import numpy as np
import requests
import time

tmdb_movie = Movie()

def get_genre(x):
    try:
        # Add a small delay to avoid hitting API rate limits
        time.sleep(0.25)

        # Handle empty or invalid titles
        if pd.isna(x) or x == '':
            return np.NaN

        # Search for the movie
        result = tmdb_movie.search(x)

        if not result:
            return np.NaN

        # Get the first movie result
        movie_id = result[0].id

        # Make API request for movie details
        response = requests.get(
            f'https://api.themoviedb.org/3/movie/{movie_id}',
            params={'api_key': tmdb.api_key}
        )

        # Check if request was successful
        if response.status_code != 200:
            return np.NaN

        data_json = response.json()

        # Extract genres
        if data_json.get('genres'):
            genres = [genre['name'] for genre in data_json['genres']]
            return ' '.join(genres)

        return np.NaN

    except Exception as e:
        print(f"Error processing title '{x}': {str(e)}")
        return np.NaN

# Apply the function to the dataframe with progress tracking
from tqdm import tqdm
tqdm.pandas()
df_2022['genres'] = df_2022['Title'].progress_map(lambda x: get_genre(str(x)))
# Out:
#  22%|██▏       | 70/321 [00:38<02:04,  2.01it/s]
# Error processing title 'Apollo 10 1⁄2: A Space Age Childhood': getattr(): attribute name must be string
# 100%|██████████| 321/321 [02:58<00:00,  1.80it/s]
# <ipython-input-51-ae8480e60a46>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].progress_map(lambda x: get_genre(str(x)))

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

df_2022.loc[:,'director_name'] = df_2022.loc[:,'Cast and crew'].map(lambda x: get_director(str(x)))
df_2022.loc[:,'actor_1_name'] = df_2022.loc[:,'Cast and crew'].map(lambda x: get_actor1(str(x)))
df_2022.loc[:,'actor_2_name'] = df_2022.loc[:,'Cast and crew'].map(lambda x: get_actor2(str(x)))
df_2022.loc[:,'actor_3_name'] = df_2022.loc[:,'Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-52-602c4b4e144b>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.loc[:,'director_name'] = df_2022.loc[:,'Cast and crew'].map(lambda x: get_director(str(x)))
# <ipython-input-52-602c4b4e144b>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.loc[:,'actor_1_name'] = df_2022.loc[:,'Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
df_22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_22['comb'] = df_22['actor_1_name'] + ' ' + df_22['actor_2_name'] + ' '+ df_22['actor_3_name'] + ' '+ df_22['director_name'] +' ' + df_22['genres']

# %%
df_22=df_22.dropna(how='any')

# %%
df_22.loc[:,'movie_title']=df_22.loc[:,'movie_title'].str.lower()

# %%
df_22
# Out:
#                             director_name       actor_1_name     actor_2_name  \
# 0                           Simon Kinberg   Jessica Chastain    Penélope Cruz
# 1                  Patricia Harris Seeley      Autumn Reeser      Danny Trejo
# 3                       Edward John Drake  Timothy V. Murphy     Bruce Willis
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera    Mason Gooding
# 5           Derek Drymon, Jennifer Kluska       Andy Samberg     Selena Gomez
# ..                                    ...                ...              ...
# 312                          Kasi Lemmons        Naomi Ackie    Stanley Tucci
# 313                          Scott Cooper     Christian Bale    Harry Melling
# 314                          Sarah Polley        Rooney Mara       Claire Foy
# 315                          Marc Forster          Tom Hanks  Mariana Treviño
# 316                            Mary Nighy      Anna Kendrick  Kaniehtiio Horn
#
# ...

# %%
df_upto_22=pd.concat([df_old,df_22],ignore_index=True)

# %%
df_upto_22
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6528       Kasi Lemmons      Naomi Ackie     Stanley Tucci
# 6529       Scott Cooper   Christian Bale     Harry Melling
# 6530       Sarah Polley      Rooney Mara        Claire Foy
# 6531       Marc Forster        Tom Hanks   Mariana Treviño
# 6532         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %% [markdown]
# # **2023**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')
tables = soup.find_all('table',class_='wikitable sortable')

import pandas as pd
from io import StringIO

df1 = pd.read_html(StringIO(str(tables[0])))[0]
df2 = pd.read_html(StringIO(str(tables[1])))[0]
df3 = pd.read_html(StringIO(str(tables[2])))[0]
df4 = pd.read_html(StringIO(str(tables[3]).replace("'1\"\'", '"1"')))[0]

df=pd.concat([df1,df2,df3,df4],ignore_index=True)
df_2023 = df[['Title','Cast and crew']]
df_2023
# Out:
#                     Title                                      Cast and crew
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 338                Memory  Michel Franco (director/screenplay); Jessica C...
# 339      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 340  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 341               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 342            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
# [343 rows x 2 columns]

# %%
from tmdbv3api import Movie
import numpy as np
import requests
import time

tmdb_movie = Movie()

def get_genre(x):
    try:
        # Add a small delay to avoid hitting API rate limits
        time.sleep(0.25)

        # Handle empty or invalid titles
        if pd.isna(x) or x == '':
            return np.NaN

        # Search for the movie
        result = tmdb_movie.search(x)

        if not result:
            return np.NaN

        # Get the first movie result
        movie_id = result[0].id

        # Make API request for movie details
        response = requests.get(
            f'https://api.themoviedb.org/3/movie/{movie_id}',
            params={'api_key': tmdb.api_key}
        )

        # Check if request was successful
        if response.status_code != 200:
            return np.NaN

        data_json = response.json()

        # Extract genres
        if data_json.get('genres'):
            genres = [genre['name'] for genre in data_json['genres']]
            return ' '.join(genres)

        return np.NaN

    except Exception as e:
        print(f"Error processing title '{x}': {str(e)}")
        return np.NaN

# Apply the function to the dataframe with progress tracking
from tqdm import tqdm
tqdm.pandas()
df_2023['genres'] = df_2023['Title'].progress_map(lambda x: get_genre(str(x)))
# Out:
# 100%|██████████| 343/343 [03:12<00:00,  1.78it/s]
# <ipython-input-63-7bf029d59f97>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['genres'] = df_2023['Title'].progress_map(lambda x: get_genre(str(x)))

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

df_2023.loc[:,'director_name'] = df_2023.loc[:,'Cast and crew'].map(lambda x: get_director(str(x)))
df_2023.loc[:,'actor_1_name'] = df_2023.loc[:,'Cast and crew'].map(lambda x: get_actor1(str(x)))
df_2023.loc[:,'actor_2_name'] = df_2023.loc[:,'Cast and crew'].map(lambda x: get_actor2(str(x)))
df_2023.loc[:,'actor_3_name'] = df_2023.loc[:,'Cast and crew'].map(lambda x: get_actor3(str(x)))

df_2023 = df_2023.rename(columns={'Title':'movie_title'})

df_23 = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

df_23['comb'] = df_23['actor_1_name'] + ' ' + df_23['actor_2_name'] + ' '+ df_23['actor_3_name'] + ' '+ df_23['director_name'] +' ' + df_23['genres']

df_23=df_23.dropna(how='any')

df_23.loc[:,'movie_title']=df_23.loc[:,'movie_title'].str.lower()
# Out:
# <ipython-input-64-64bbdecd22f0>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023.loc[:,'director_name'] = df_2023.loc[:,'Cast and crew'].map(lambda x: get_director(str(x)))
# <ipython-input-64-64bbdecd22f0>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023.loc[:,'actor_1_name'] = df_2023.loc[:,'Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_23
# Out:
#             director_name      actor_1_name       actor_2_name  \
# 0        Gerard Johnstone  Allison Williams      Violet McGraw
# 2       Nathan Frankowski   Alice Orr-Ewing          Joe Doyle
# 3    Jean-François Richet     Gerard Butler        Mike Colter
# 4                Calmatic        Tosin Cole     Jacob Latimore
# 5              John Hyams      Gideon Adlon  Bethlehem Million
# ..                    ...               ...                ...
# 338         Michel Franco  Jessica Chastain    Peter Sarsgaard
# 339        Blitz Bazawule  Fantasia Barrino   Taraji P. Henson
# 340        George Clooney     Callum Turner      Joel Edgerton
# 341          Michael Mann       Adam Driver      Penelope Cruz
# 342              Dan Levy          Dan Levy         Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# ...

# %%
df_upto_23=pd.concat([df_upto_22,df_23],ignore_index=True)

# %%
df_upto_23
# Out:
#           director_name      actor_1_name      actor_2_name  \
# 0         James Cameron       CCH Pounder  Joel David Moore
# 1        Gore Verbinski       Johnny Depp     Orlando Bloom
# 2            Sam Mendes   Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan         Tom Hardy    Christian Bale
# 4           Doug Walker       Doug Walker        Rob Walker
# ...                 ...               ...               ...
# 6852      Michel Franco  Jessica Chastain   Peter Sarsgaard
# 6853     Blitz Bazawule  Fantasia Barrino  Taraji P. Henson
# 6854     George Clooney     Callum Turner     Joel Edgerton
# 6855       Michael Mann       Adam Driver     Penelope Cruz
# 6856           Dan Levy          Dan Levy        Ruth Negga
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
df_upto_23.to_csv('full_movie_dataset_upto_2023')
